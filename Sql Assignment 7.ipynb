# %%
import mysql.connector as conn

# %%
conn.connect(host = 'localhost',user = 'root' ,passwd = "black97tiger19")

# %%
mydb = conn.connect(host = 'localhost',user = 'root' ,passwd = "black97tiger19")

# %%
cursor = mydb.cursor()

# %%
import pandas as pd

# %%
pd.read_sql("select * from SqlAssignment.worker",mydb)
# Out:
#     ind  emplyeeid firstname  lastname         department  salary  \
# 0     1       9369      TONY     STARK  SOFTWARE ENGINEER    7902
# 1     2       9499       TIM     ADOLF           SALESMAN    7698
# 2     3       9566       KIM    JARVIS            MANAGER    7839
# 3     4       9654       SAM     MILES           SALESMAN    7698
# 4     5       9782     KEVIN      HILL            MANAGER    7839
# 5     6       9788    CONNIE     SMITH            ANALYST    7566
# 6     7       9839    ALFRED   KINSLEY          PRESIDENT    7566
# 7     8       9844      PAUL   TIMOTHY           SALESMAN    7698
# 8     9       9876      JOHN    ASGHAR  SOFTWARE ENGINEER    7788
# 9    10       9900      ROSE   SUMMERS     TECHNICAL LEAD    7698
# 10   11       9902    ANDREW  FAULKNER           ANAYLYST    7566
# 11   12       9934     KAREN  MATTHEWS  SOFTWARE ENGINEER    7782
# 12   13       9591     WENDY     SHAWN           SALESMAN    7698
# ...

# %%
#1
cursor.execute("select * from sqlassignment.worker where emplyeeid IN(select emplyeeid from sqlassignment.worker where ind%2!=0)")

# %%
cursor.fetchall()
# Out:
# [(1,
#   9369,
#   'TONY',
#   'STARK',
#   'SOFTWARE ENGINEER',
#   7902,
#   datetime.date(1980, 12, 17),
#   'tony@ineuron.in'),
#  (3,
#   9566,
#   'KIM',
#   'JARVIS',
#   'MANAGER',
#   7839,
#   datetime.date(1981, 4, 2),
#   'IM@ineuron.in'),
#  (5,
#   9782,
#   'KEVIN',
#   'HILL',
#   'MANAGER',
#   7839,
#   datetime.date(1981, 6, 9),
#   'kevin@ineuron.in'),
#  (7,
#   9839,
#   'ALFRED',
#   'KINSLEY',
#   'PRESIDENT',
#   7566,
#   datetime.date(1981, 11, 17),
#   'alfred@ieuron.in'),
#  (9,
#   9876,
#   'JOHN',
#   'ASGHAR',
#   'SOFTWARE ENGINEER',
#   7788,
#   datetime.date(1983, 1, 12),
#   'john@ineuron.in'),
#  (11,
#   9902,
#   'ANDREW',
#   'FAULKNER',
#   'ANAYLYST',
#   7566,
#   datetime.date(1981, 12, 3),
#   'andrew'),
#  (13,
#   9591,
#   'WENDY',
#   'SHAWN',
#   'SALESMAN',
#   7698,
#   datetime.date(1981, 2, 22),
#   'wendy@ineuron.in'),
#  (15,
#   9777,
#   'MADII',
#   'HIMBURY',
#   'ANALYST',
#   7839,
#   datetime.date(1981, 5, 1),
# ...

# %%
#2 
cursor.execute("create table sqlassignment.workerclone like SqlAssignment.worker")
cursor.execute("insert into sqlassignment.workerclone(select * from SqlAssignment.worker )")

# %%
mydb.commit()

# %%
cursor.execute("select * from SqlAssignment.workerclone ")

# %%
cursor.fetchall()
# Out:
# [(1,
#   9369,
#   'TONY',
#   'STARK',
#   'SOFTWARE ENGINEER',
#   7902,
#   datetime.date(1980, 12, 17),
#   'tony@ineuron.in'),
#  (2,
#   9499,
#   'TIM',
#   'ADOLF',
#   'SALESMAN',
#   7698,
#   datetime.date(1981, 2, 20),
#   'tim@ineuron.in'),
#  (3,
#   9566,
#   'KIM',
#   'JARVIS',
#   'MANAGER',
#   7839,
#   datetime.date(1981, 4, 2),
#   'IM@ineuron.in'),
#  (4,
#   9654,
#   'SAM',
#   'MILES',
#   'SALESMAN',
#   7698,
#   datetime.date(1981, 9, 28),
#   'sam@ineuron.in'),
#  (5,
#   9782,
#   'KEVIN',
#   'HILL',
#   'MANAGER',
#   7839,
#   datetime.date(1981, 6, 9),
#   'kevin@ineuron.in'),
#  (6,
#   9788,
#   'CONNIE',
#   'SMITH',
#   'ANALYST',
#   7566,
#   datetime.date(1982, 12, 9),
#   'smith@ineuron.in'),
#  (7,
#   9839,
#   'ALFRED',
#   'KINSLEY',
#   'PRESIDENT',
#   7566,
#   datetime.date(1981, 11, 17),
#   'alfred@ieuron.in'),
#  (8,
#   9844,
#   'PAUL',
#   'TIMOTHY',
#   'SALESMAN',
#   7698,
#   datetime.date(1981, 9, 8),
# ...
